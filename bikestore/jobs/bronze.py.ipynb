# %%
from bikestore.processors.dynamic_pipeline import DynamicPipeline
# ============================================
# CONFIG
# ============================================
resource_path = "/Volumes/bikestore/resource/01-origem/"
bronze_path = "bikestore.bronze"
quarantine_path = "bikestore.silver_quarentena"

bronze_map = {
    "tmp_bronze_brands":      f"{bronze_path}brands.csv",
    "tmp_bronze_categories":  f"{bronze_path}categories.csv",
    "tmp_bronze_customers":   f"{bronze_path}customers.csv",
    "tmp_bronze_order_items": f"{bronze_path}order_items.csv",
    "tmp_bronze_orders":      f"{bronze_path}orders.csv",
    "tmp_bronze_products":    f"{bronze_path}products.csv",
    "tmp_bronze_staffs":      f"{bronze_path}staffs.csv",
    "tmp_bronze_stocks":      f"{bronze_path}stocks.csv",
    "tmp_bronze_stores":      f"{bronze_path}stores.csv",
}

# ============================================
# EXECUÇÃO
# ============================================
pipeline = DynamicPipeline(
    spark=spark,  # já existe no Databricks
    bronze_map=bronze_map,
    validation_map="",
    silver_path=bronze_path,
    quarantine_path=quarantine_path
)

pipeline.run()

print("🏁 Pipeline finalizado com sucesso!")
